# %% [markdown]
# #### Bibliotecas

# %%
import sys
import tweepy as tw
import pandas as pd

if '/Users/will/Google Drive/workspace/Projetos/projeto_cangaco' not in sys.path:
    sys.path.insert(0, '/Users/will/Google Drive/workspace/Projetos/projeto_cangaco')
if '/Users/will/Google Drive/workspace/Projetos/projeto_cangaco/maria_bonita/conjunto_dados' not in sys.path:
    sys.path.insert(0, '/Users/will/Google Drive/workspace/Projetos/projeto_cangaco/maria_bonita/conjunto_dados')

from utilidades.autenticacao import autenticar
import maria_bonita.conjunto_dados.utilidades.captura.StreamListenerPersonalizado as slp
import maria_bonita.conjunto_dados.utilidades.captura.API_Personalizada as ap
from maria_bonita.conjunto_dados.utilidades.captura.chaves_busca import MISOGINIA
import maria_bonita.conjunto_dados.utilidades.captura.ferramentas_conjunto_dados as fcd
import maria_bonita.conjunto_dados.utilidades.pre_processamento.novas_variaveis as nv

# %% [markdown]
# #### Parâmetros

# %%
# DEFINIR PARÂMETROS !!!
chaves_escolhidas = [MISOGINIA]

chaves_busca, quantidade_tweets, com_retweets, \
idiomas, caminho_dataset = fcd.parametros(chaves_busca=chaves_escolhidas,
                                          quantidade_tweets=30)

# %% [markdown]
# #### Rotina

# %%
auth = autenticar()
lista_tweets = []

minha_stream = None
minha_stream = tw.Stream(auth=auth,
                         listener=slp.StreamListenerPersonalizado(lista_resultados=lista_tweets,
                                                                  quantidade_tweets=quantidade_tweets,
                                                                  com_retweets=com_retweets))

minha_stream.filter(languages=idiomas,
                    track=chaves_busca)
# Out:
# 1 -----------------------------------------------------------------------
# Usuário: jp_m00n
# Texto: @LeticiaShirakin Vc é puta de luxo?
# ------------------------------------------------------------------------
#
# 2 -----------------------------------------------------------------------
# Usuário: bleigholy
# Texto: SÉRIO DESCULPA @cetriaeb https://t.co/3BRpOFj7PI
# ------------------------------------------------------------------------
#
# 3 -----------------------------------------------------------------------
# Usuário: heeeydiias
# Texto: Eu tô muito puta da vida mds
# ------------------------------------------------------------------------
#
# 4 -----------------------------------------------------------------------
# Usuário: Purple_Lilium
# Texto: Meu irmão um dia me perguntou que pessoa que eu gostaria de dar um soco. Antes não vinha um nome na cabeça mas agor… https://t.co/3oO1BTwrkx
# ------------------------------------------------------------------------
#
# 5 -----------------------------------------------------------------------
# Usuário: taefmi
# Texto: eu mesma estraguei o dia com irresponsabilidade minha puta que pariu serio
# ------------------------------------------------------------------------
#
# 6 -----------------------------------------------------------------------
# Usuário: magicvnte
# Texto: to extremamente puta com esse ngc da sabrina
# ------------------------------------------------------------------------
#
# 7 -----------------------------------------------------------------------
# Usuário: JPVargas2208
# Texto: Bruno encontra as amigas dele até na puta que pariu, é impressionante
# ------------------------------------------------------------------------
#
# 8 -----------------------------------------------------------------------
# Usuário: skapism
# Texto: @placibu que delícia
# ------------------------------------------------------------------------
#
# 9 -----------------------------------------------------------------------
# Usuário: ttokeef
# Texto: semibissexual nos trends os cara ainda bola pra esse tipo de coisa puta que pariu
# ------------------------------------------------------------------------
#
# 10 ----------------------------------------------------------------------
# Usuário: manuelaseverino
# Texto: As vezes eu só queria dar uma paulada nela lkkkk MALUCA https://t.co/5LyaSq2k3Y
# ------------------------------------------------------------------------
#
# 11 ----------------------------------------------------------------------
# Usuário: ferkkjk
# Texto: atenção essa gostosa está com fome https://t.co/IKMO0dIJH4
# ------------------------------------------------------------------------
#
# 12 ----------------------------------------------------------------------
# Usuário: _laryyyy
# Texto: filha da puta gostosa
# ------------------------------------------------------------------------
#
# 13 ----------------------------------------------------------------------
# Usuário: tenphrodite
# Texto: se sentir raiva emagrecesse, eu nn tava fazendo dieta pq olha puta merda
# ------------------------------------------------------------------------
#
# 14 ----------------------------------------------------------------------
# Usuário: engcampelo
# Texto: A @oi_oficial sendo OI NOVAMENTE. Se essa empresa não tivesse em falência judicial viu.... puta que pariu.
# ------------------------------------------------------------------------
#
# 15 ----------------------------------------------------------------------
# Usuário: wescorpiao
# Texto: @thiugo Vc é piranha e come peixe direto
# ------------------------------------------------------------------------
#
# 16 ----------------------------------------------------------------------
# Usuário: Nicolinho05
# Texto: Gostosa boca de veludo kkkkkkkkk
# ------------------------------------------------------------------------
#
# 17 ----------------------------------------------------------------------
# Usuário: Trundle
# Texto: @zerovoid__ vc e um filho da puta entao
# ------------------------------------------------------------------------
#
# 18 ----------------------------------------------------------------------
# Usuário: Victorfp87
# Texto: @CNNBrasil Nham que delicia
# ------------------------------------------------------------------------
#
# 19 ----------------------------------------------------------------------
# Usuário: camizelbra
# Texto: fiz bife c farinha panko na air fryer e ficou uma delicia
# ------------------------------------------------------------------------
#
# 20 ----------------------------------------------------------------------
# Usuário: gabivjuliano
# Texto: @mserravalle_ te amo, gostosa
# ------------------------------------------------------------------------
#
# 21 ----------------------------------------------------------------------
# Usuário: _pimentani_
# Texto: uma grande gostosa
# ------------------------------------------------------------------------
#
# 22 ----------------------------------------------------------------------
# Usuário: MaltasOnTheChat
# Texto: Que filha da puta
# ------------------------------------------------------------------------
#
# 23 ----------------------------------------------------------------------
# Usuário: Jully_Ribeiro8
# Texto: essa piranha não me responde
# ------------------------------------------------------------------------
#
# 24 ----------------------------------------------------------------------
# Usuário: projimise
# Texto: fui na casa da anna e o marido dela tava uma delícia (o bolo dele obv
# ------------------------------------------------------------------------
#
# 25 ----------------------------------------------------------------------
# Usuário: jnkwebs
# Texto: sonhei q minha mãe era louca e eu tinha tinha q machucar ela pra fugir
# :((
# ------------------------------------------------------------------------
#
# 26 ----------------------------------------------------------------------
# Usuário: _mahfurlan
# Texto: @know_gx @dearjooh KAKSKSKAKAKAKAK PUTA Q PARIU
# ------------------------------------------------------------------------
#
# 27 ----------------------------------------------------------------------
# Usuário: anajuuxzz
# Texto: @algumacoisasamy toma vc puta
# ------------------------------------------------------------------------
#
# 28 ----------------------------------------------------------------------
# Usuário: hwgoyu
# Texto: ta todo mundo tao lindo puta q pariu https://t.co/tHOr8zMrEZ
# ------------------------------------------------------------------------
#
# 29 ----------------------------------------------------------------------
# Usuário: JIH0SMILE
# Texto: Misericórdia, ela vem e diz "send me pack of the foot" PUTA QUE PARIU VOU RACHAR
# ------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-e56265480ed7> in <module>
#       8                                                                   com_retweets=com_retweets))
#       9
# ---> 10 minha_stream.filter(languages=idiomas,
#      11                     track=chaves_busca)
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# ~\anaconda3\lib\http\client.py in read(self, amt)
#     452             # Amount is given, implement using readinto
#     453             b = bytearray(amt)
# --> 454             n = self.readinto(b)
#     455             return memoryview(b)[:n].tobytes()
#     456         else:
#
# ~\anaconda3\lib\http\client.py in readinto(self, b)
#     486
#     487         if self.chunked:
# --> 488             return self._readinto_chunked(b)
#     489
#     490         if self.length is not None:
#
# ~\anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     581         try:
#     582             while True:
# --> 583                 chunk_left = self._get_chunk_left()
#     584                 if chunk_left is None:
#     585                     return total_bytes
#
# ~\anaconda3\lib\http\client.py in _get_chunk_left(self)
#     549                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     550             try:
# --> 551                 chunk_left = self._read_next_chunk_size()
#     552             except ValueError:
#     553                 raise IncompleteRead(b'')
#
# ~\anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     509     def _read_next_chunk_size(self):
#     510         # Read the next chunk size from the file
# --> 511         line = self.fp.readline(_MAXLINE + 1)
#     512         if len(line) > _MAXLINE:
#     513             raise LineTooLong("chunk size")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Visualização

# %%
conjunto_dados = pd.DataFrame(lista_tweets)
conjunto_dados.head()
# Out:
#             criado_em  retweet             tweet_id  \
# 0 2020-12-03 15:25:04    False  1334519027218132993
# 1 2020-12-03 15:25:05    False  1334519028249976834
# 2 2020-12-03 15:25:05    False  1334519031009828867
# 3 2020-12-03 15:25:05    False  1334519031236354049
# 4 2020-12-03 15:25:06    False  1334519032352018433
#
#                                            tweet_url  \
# 0  https://twitter.com/jp_m00n/status/13345190272...
# 1  https://twitter.com/bleigholy/status/133451902...
# 2  https://twitter.com/heeeydiias/status/13345190...
# 3  https://twitter.com/Purple_Lilium/status/13345...
# 4  https://twitter.com/taefmi/status/133451903235...
#
#                                          tweet_texto tweet_hashtags  \
# 0                @LeticiaShirakin Vc é puta de luxo?             []
# 1   SÉRIO DESCULPA @cetriaeb https://t.co/3BRpOFj7PI             []
# 2                       Eu tô muito puta da vida mds             []
# 3  Meu irmão um dia me perguntou que pessoa que e...             []
# 4  eu mesma estraguei o dia com irresponsabilidad...             []
#
#   tweet_urls_externos                         tweet_usuarios_mencionados  \
# 0                  []  [{'screen_name': 'LeticiaShirakin', 'id_str': ...
# 1                  []  [{'screen_name': 'cetriaeb', 'id_str': '366002...
# 2                  []                                                 []
# 3                  []                                                 []
# 4                  []                                                 []
#
#   tweet_plataforma_origem                                  tweet_em_resposta  \
# 0                 Android  {'resposta_ao_tweet': '1334502429463891970', '...
# 1                  iPhone                                               None
# 2                  iPhone                                               None
# 3                  iPhone                                               None
# 4                  iPhone                                               None
#
#    ... usuario_verificado        usuario_localizacao  \
# 0  ...              False  conta reserva:@reserva_jp
# 1  ...              False                       None
# 2  ...              False    Santo Anastácio, Brasil
# 3  ...              False                       None
# 4  ...              False                       None
#
#                                    usuario_descricao usuario_qtd_seguidores  \
# 0            ⠀✩o\ele\o✩multi-fandom✩minor✩aquileano✩                    439
# 1                                 monogamia sigilosa                   1442
# 2                                  Free soul §tulip§                    100
# 3  Nola l 2.5 l §badger§§yellow heart§§black hear...                     59
# 4  if you’re not seokjin’s scream in dionysus the...                    288
#
#   usuario_qtd_amigos usuario_qtd_tweets  usuario_url_imagem_perfil  \
# 0                448               8014
# 1                969              26559
# 2                 65               5413
# 3                269               2683
# 4                278               2141
#
#   usuario_url_imagem_capa   usuario_criado_em  \
# 0                         2019-10-07 01:50:20
# 1                         2014-09-14 15:30:16
# 2                         2019-01-14 04:07:18
# 3                         2014-09-04 17:56:15
# 4                         2020-05-14 20:05:20
#
#                                         usuario_json
# 0  {'id': 1181023873791401984, 'id_str': '1181023...
# 1  {'id': 2770110669, 'id_str': '2770110669', 'na...
# 2  {'id': 1084663220923699200, 'id_str': '1084663...
# 3  {'id': 2761400909, 'id_str': '2761400909', 'na...
# 4  {'id': 1261024791907229701, 'id_str': '1261024...
#
# [5 rows x 40 columns]

# %% [markdown]
# #### Consolidar dados

# %%
if not "conjunto_dados" in locals():
    conjunto_dados = pd.DataFrame(lista_tweets)
conjunto_dados.to_csv(caminho_dataset, sep=';', index=False, encoding='utf-8-sig')

# %% [markdown]
# #### Pré-processamento

# %%
# Com conexão no end-point

if not "conjunto_dados" in locals():
    conjunto_dados = pd.read_csv(caminho_dataset, sep=';')

API = ap.API()
conjunto_dados['tweet_usuarios_mencionados'] = conjunto_dados.apply(lambda x: fcd.relacionamento_com_mencionados(API=API,
                                                                                                                 usuario_id_origem=x["usuario_id"],
                                                                                                                 mencionados=x['tweet_usuarios_mencionados']),
                                                                    axis=1)

API = ap.API()
conjunto_dados['tweet_em_resposta'] = conjunto_dados.apply(lambda x: fcd.relacionamento_com_respondido(API=API,
                                                                                                       usuario_id_origem=x["usuario_id"],
                                                                                                       mencionados=x['tweet_usuarios_mencionados'],
                                                                                                       em_resposta=x['tweet_em_resposta']), axis=1)

conjunto_dados.to_csv(caminho_dataset, sep=';', index=False, encoding='utf-8-sig')
# Out:
# Chamadas API: 1/118
#
# Chamadas API: 2/118
#
# Chamadas API: 3/118
#
# Chamadas API: 4/118
#
# Chamadas API: 5/118
#
# Chamadas API: 6/118
#
# Chamadas API: 7/118
#
# Chamadas API: 8/118
#
# Chamadas API: 9/118
#
# Chamadas API: 10/118
#
# Chamadas API: 11/118

# %%
# Sem conexão no end-point

if not "conjunto_dados" in locals():
    conjunto_dados = pd.read_csv(caminho_dataset, sep=';')
    
conjunto_dados['relacionamento_com_mencionados'] = conjunto_dados['tweet_usuarios_mencionados'].apply(lambda x: nv.relacionamento_com_mencionados(mencionados=x))

conjunto_dados['relacionamento_com_respondido'] = conjunto_dados['tweet_em_resposta'].apply(lambda x: nv.relacionamento_com_respondido(em_resposta=x))

conjunto_dados['texto_original'] = conjunto_dados['tweet_texto']

conjunto_dados['tokens'] = conjunto_dados.apply(lambda x: nv.tokenizar(tweet_texto=x['tweet_texto'],
                                                                       chaves_busca=chaves_escolhidas,
                                                                       mencionados=x['tweet_usuarios_mencionados']),
                                                axis=1)

conjunto_dados['possivel_infracao'] = ''

conjunto_dados.to_csv(caminho_dataset, sep=';', index=False, encoding='utf-8-sig')
