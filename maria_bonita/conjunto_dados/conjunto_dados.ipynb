# %% [markdown]
# #### Bibliotecas

# %%
import sys
import tweepy as tw
import pandas as pd

if '/Users/will/Google Drive/workspace/Projetos/projeto_cangaco' not in sys.path:
    sys.path.insert(0, '/Users/will/Google Drive/workspace/Projetos/projeto_cangaco')
if '/Users/will/Google Drive/workspace/Projetos/projeto_cangaco/maria_bonita/conjunto_dados' not in sys.path:
    sys.path.insert(0, '/Users/will/Google Drive/workspace/Projetos/projeto_cangaco/maria_bonita/conjunto_dados')

from autenticacao import autenticar
import maria_bonita.conjunto_dados.utilidades.captura.StreamListenerPersonalizado as slp
import maria_bonita.conjunto_dados.utilidades.captura.APIPersonalizada as ap
from maria_bonita.conjunto_dados.utilidades.captura.chaves_busca import LISTA_GERAL, ANTIPETISMO, INTOLERANCIA_RELIGIOSA, GORDOFOBIA, HOMOFOBIA, \
MISOGINIA, PEDOFILIA, RACISMO
import maria_bonita.conjunto_dados.utilidades.captura.ferramentas_conjunto_dados as fcd
import maria_bonita.conjunto_dados.utilidades.pre_processamento.novas_variaveis as nv

# %% [markdown]
# #### Parâmetros

# %%
# DEFINIR PARÂMETROS !!!
chaves_escolhidas = [MISOGINIA]

chaves_busca, quantidade_tweets, com_retweets, \
idiomas, caminho_dataset = fcd.parametros(chaves_busca=chaves_escolhidas,
                                          quantidade_tweets=30)

# %% [markdown]
# #### Rotina

# %%
auth = autenticar()
lista_tweets = []

minha_stream = None
minha_stream = tw.Stream(auth=auth,
                         listener=slp.StreamListenerPersonalizado(lista_resultados=lista_tweets,
                                                                  quantidade_tweets=quantidade_tweets,
                                                                  com_retweets=com_retweets))

minha_stream.filter(languages=idiomas,
                    track=chaves_busca)
# Out:
# 1 -----------------------------------------------------------------------
# Usuário: marina20004595
# Texto: @Flaviamaynarte Se você sabe qual é a sensação de precisar e não ter com quem contar, talvez entenda qual é a sensa… https://t.co/yF4AoTXjke
# ------------------------------------------------------------------------
#
# 2 -----------------------------------------------------------------------
# Usuário: nalu_dss
# Texto: Engraçado né, a pessoa fica puta pq eu trato ela do jeito q ela me trata
# Ah vai a merda
# ------------------------------------------------------------------------
#
# 3 -----------------------------------------------------------------------
# Usuário: almeidapgabi
# Texto: protetora gostosa 🙏🏽
# ------------------------------------------------------------------------
#
# 4 -----------------------------------------------------------------------
# Usuário: rinnezan
# Texto: do nd deu a louca e comecei a postar um monte de foto do sasuke nos stts nem sei como tem gente q ainda vê
# ------------------------------------------------------------------------
#
# 5 -----------------------------------------------------------------------
# Usuário: LucasCruzlrdq
# Texto: @rizinbrabo @videosmaiconkus @maiconkusterk Cara e nojento pra krlh e uma puta falta de higiene, então pode gastar a vontade
# Rotina: maria_bonita.conjunto_dados.utilidades.captura.info_tweet.autor
# Erro: expected string or bytes-like object
# Rotina: maria_bonita.conjunto_dados.utilidades.captura.StreamListenerPersonalizado.on_status
# Erro: 'charmap' codec can't encode character '\U0001f365' in position 1533: character maps to <undefined>
# 5 -----------------------------------------------------------------------
# Usuário: paulohcamorim
# Texto: tive uma crise de riso tão gostosa com essa aqui https://t.co/ea54xkBzow
# ------------------------------------------------------------------------
#
# 6 -----------------------------------------------------------------------
# Usuário: Hfvasconcelos
# Texto: PUTA QUE PARIU FLASH POSE
# ------------------------------------------------------------------------
#
# 7 -----------------------------------------------------------------------
# Usuário: erangelcrf
# Texto: da vontade de tacar fogo no piru desse filho da puta
# ------------------------------------------------------------------------
#
# 8 -----------------------------------------------------------------------
# Usuário: spacemouse79
# Texto: @lua_jupiter @asap_rud filho da puta como ele sabe disso?
# ------------------------------------------------------------------------
#
# 9 -----------------------------------------------------------------------
# Usuário: lilbowika
# Texto: @itsmecanddie vc eh muiito loka kkkkkkk
# ------------------------------------------------------------------------
#
# 10 ----------------------------------------------------------------------
# Usuário: DuliWanju
# Texto: Agora eu tenho que economizar pra comprar uma vaquinha rosa. 🐮🌹
# ------------------------------------------------------------------------
#
# 11 ----------------------------------------------------------------------
# Usuário: summerrains_
# Texto: Agora falando dos fatos importantes a mulher do Pacha eh uma gostosa de alto nível
# ------------------------------------------------------------------------
#
# 12 ----------------------------------------------------------------------
# Usuário: blazednoff
# Texto: é humanamente impossível salvaje ficar melhor que a original mas o remix ficou uma delicia ui ui https://t.co/3JQYyXED69
# ------------------------------------------------------------------------
#
# 13 ----------------------------------------------------------------------
# Usuário: zabszab
# Texto: se eu já sou mui louca com uma menstruação no mês imagina com duas o bagulho fica louco
# ------------------------------------------------------------------------
#
# 14 ----------------------------------------------------------------------
# Usuário: SaiiaS___
# Texto: Mete com força e com talento estou ofegante e você percebendo bate e maltrata essa puta safada quero jatada de leit… https://t.co/mOwg9zmH5R
# ------------------------------------------------------------------------
#
# 15 ----------------------------------------------------------------------
# Usuário: FagnerJosdaSil6
# Texto: @Gabriel82131777 Delícia de pacote
# ------------------------------------------------------------------------
#
# 16 ----------------------------------------------------------------------
# Usuário: voss_pablo
# Texto: @porqbitchi Olha a boca piranha
# ------------------------------------------------------------------------
#
# 17 ----------------------------------------------------------------------
# Usuário: brumartinsrl
# Texto: @BarrozoLarissa @lesbicaxn Delícia
# ------------------------------------------------------------------------
#
# 18 ----------------------------------------------------------------------
# Usuário: LHRM97
# Texto: Double black? Fireball? Bombay? Puta que pariuuuuuu
# ------------------------------------------------------------------------
#
# 19 ----------------------------------------------------------------------
# Usuário: joyvrxx
# Texto: Ai sinceramente eu desisto, vocês perdem o foco por qualquer bobeira puta merda
# ------------------------------------------------------------------------
#
# 20 ----------------------------------------------------------------------
# Usuário: getwellouis
# Texto: @homelarryisreal raiva ódio cu inferno caralho puta que pariu
# ------------------------------------------------------------------------
#
# 21 ----------------------------------------------------------------------
# Usuário: imdudaok
# Texto: @kamillatamaraa Tô com sdd de vc minha gostosa
# ------------------------------------------------------------------------
#
# 22 ----------------------------------------------------------------------
# Usuário: tristanvocal
# Texto: 60 reais c o frete😍 que delícia universal https://t.co/VlUJYPM29H
# ------------------------------------------------------------------------
#
# 23 ----------------------------------------------------------------------
# Usuário: ttDJoy
# Texto: Assim de saúde KKKKKKK
# ------------------------------------------------------------------------
#
# 24 ----------------------------------------------------------------------
# Usuário: bluellost
# Texto: caralho eu amei muito essa pqp que delícia
# https://t.co/gsFwkh18fJ
# ------------------------------------------------------------------------
#
# 25 ----------------------------------------------------------------------
# Usuário: DavidWander2
# Texto: @rafael_dotado Uma delicia
# ------------------------------------------------------------------------
#
# 26 ----------------------------------------------------------------------
# Usuário: guisibilio
# Texto: Ótimo dia pra energia cair aqui em casa, puta calor do caraio. Agora os bichos vão infernizar
# ------------------------------------------------------------------------
#
# 27 ----------------------------------------------------------------------
# Usuário: simpsforblake
# Texto: @vhszilber Sua puta
# ------------------------------------------------------------------------
#
# 28 ----------------------------------------------------------------------
# Usuário: JunioJosymar
# Texto: Puta merda o galo começo doer agora vey kkakakak
# ------------------------------------------------------------------------
#
# 29 ----------------------------------------------------------------------
# Usuário: dceunext
# Texto: eu vou   achei mt gostosinha pensei q do nada o luiz gonzaga ia aparecer
# ------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-e56265480ed7> in <module>
#       8                                                                   com_retweets=com_retweets))
#       9
# ---> 10 minha_stream.filter(languages=idiomas,
#      11                     track=chaves_busca)
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# ~\anaconda3\lib\http\client.py in read(self, amt)
#     452             # Amount is given, implement using readinto
#     453             b = bytearray(amt)
# --> 454             n = self.readinto(b)
#     455             return memoryview(b)[:n].tobytes()
#     456         else:
#
# ~\anaconda3\lib\http\client.py in readinto(self, b)
#     486
#     487         if self.chunked:
# --> 488             return self._readinto_chunked(b)
#     489
#     490         if self.length is not None:
#
# ~\anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     581         try:
#     582             while True:
# --> 583                 chunk_left = self._get_chunk_left()
#     584                 if chunk_left is None:
#     585                     return total_bytes
#
# ~\anaconda3\lib\http\client.py in _get_chunk_left(self)
#     549                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     550             try:
# --> 551                 chunk_left = self._read_next_chunk_size()
#     552             except ValueError:
#     553                 raise IncompleteRead(b'')
#
# ~\anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     509     def _read_next_chunk_size(self):
#     510         # Read the next chunk size from the file
# --> 511         line = self.fp.readline(_MAXLINE + 1)
#     512         if len(line) > _MAXLINE:
#     513             raise LineTooLong("chunk size")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Visualização

# %%
conjunto_dados = pd.DataFrame(lista_tweets)
conjunto_dados.head()
# Out:
#             criado_em  retweet             tweet_id  \
# 0 2020-11-27 00:25:00    False  1332118190642618368
# 1 2020-11-27 00:25:01    False  1332118191246618625
# 2 2020-11-27 00:25:01    False  1332118191959629824
# 3 2020-11-27 00:25:01    False  1332118193306001409
# 4 2020-11-27 00:25:02    False  1332118197110235137
#
#                                            tweet_url  \
# 0  https://twitter.com/marina20004595/status/1332...
# 1  https://twitter.com/nalu_dss/status/1332118191...
# 2  https://twitter.com/almeidapgabi/status/133211...
# 3  https://twitter.com/rinnezan/status/1332118193...
# 4  https://twitter.com/paulohcamorim/status/13321...
#
#                                          tweet_texto tweet_hashtags  \
# 0  @Flaviamaynarte Se você sabe qual é a sensação...             []
# 1  Engraçado né, a pessoa fica puta pq eu trato e...             []
# 2  protetora gostosa §folded hands: medium skin t...             []
# 3  do nd deu a louca e comecei a postar um monte ...             []
# 4  tive uma crise de riso tão gostosa com essa aq...             []
#
#                                  tweet_urls_externos  \
# 0  [http://vaka.me/1056726?utm_campaign=whatsapp&...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [https://open.spotify.com/track/0NYHOqjtfbY7ov...
#
#                           tweet_usuarios_mencionados tweet_plataforma_origem  \
# 0  [{'screen_name': 'Flaviamaynarte', 'id_str': '...                  iPhone
# 1                                                 []                 Android
# 2                                                 []                  iPhone
# 3                                                 []                 Android
# 4                                                 []                  iPhone
#
#                                    tweet_em_resposta  ... usuario_verificado  \
# 0  {'resposta_ao_tweet': '1332116992610938882', '...  ...              False
# 1                                               None  ...              False
# 2                                               None  ...              False
# 3                                               None  ...              False
# 4                                               None  ...              False
#
#          usuario_localizacao  \
# 0                       None
# 1  Ah sei não, procura aí fi
# 2            jornalismo-ufrj
# 3             ㅤ𝖌𝖔𝖏𝖔𝖚 𝖘𝖆𝖙𝖔𝖗𝖚ㅤ
# 4        Divinópolis, Brasil
#
#                                    usuario_descricao usuario_qtd_seguidores  \
# 0  Pt§triangular flag§§triangular flag§§triangula...                    144
# 1        Insta: @nalu_ds\nPerdi a outra conta amigux                     16
# 2                                    flightless bird                    585
# 3  ⠀⠀⠀⠀⠀§seedling§ 𝘪 𝘭𝘰𝘷𝘦 𝙪𝙘𝙝𝙞𝙝𝙖 𝘤𝘰𝘶𝘱𝘭𝘦!! §tulip§...                   3015
# 4                                me faltam palavrões                    206
#
#   usuario_qtd_amigos usuario_qtd_tweets  usuario_url_imagem_perfil  \
# 0                286                142
# 1                 63                 99
# 2                420              11824
# 3               2689              10987
# 4                239               7549
#
#   usuario_url_imagem_capa   usuario_criado_em  \
# 0                         2020-11-25 20:40:56
# 1                         2020-11-21 22:16:46
# 2                         2015-08-04 17:51:17
# 3                         2020-01-10 00:19:55
# 4                         2016-03-20 01:05:50
#
#                                         usuario_json
# 0  {'id': 1331699363849101312, 'id_str': '1331699...
# 1  {'id': 1330273913792835593, 'id_str': '1330273...
# 2  {'id': 3403031843, 'id_str': '3403031843', 'na...
# 3  {'id': 1215427983785254913, 'id_str': '1215427...
# 4  {'id': 711358049844334593, 'id_str': '71135804...
#
# [5 rows x 40 columns]

# %% [markdown]
# #### Consolidar dados

# %%
if not "conjunto_dados" in locals():
    conjunto_dados = pd.DataFrame(lista_tweets)
conjunto_dados.to_csv(caminho_dataset, sep=';', index=False, encoding='utf-8-sig')

# %% [markdown]
# #### Pré-processamento

# %%
# Com conexão no end-point

if not "conjunto_dados" in locals():
    conjunto_dados = pd.read_csv(caminho_dataset, sep=';')

API = ap.API()
conjunto_dados['tweet_usuarios_mencionados'] = conjunto_dados.apply(lambda x: fcd.relacionamento_com_mencionados(API=API,
                                                                                                                 usuario_id_origem=x["usuario_id"],
                                                                                                                 mencionados=x['tweet_usuarios_mencionados']),
                                                                    axis=1)

API = ap.API()
conjunto_dados['tweet_em_resposta'] = conjunto_dados.apply(lambda x: fcd.relacionamento_com_respondido(API=API,
                                                                                                       usuario_id_origem=x["usuario_id"],
                                                                                                       mencionados=x['tweet_usuarios_mencionados'],
                                                                                                       em_resposta=x['tweet_em_resposta']), axis=1)

conjunto_dados.to_csv(caminho_dataset, sep=';', index=False, encoding='utf-8-sig')
# Out:
# Chamadas API: 1/179
#
# Chamadas API: 2/179
#
# Chamadas API: 3/179
#
# Chamadas API: 4/179
#
# Chamadas API: 5/179
#
# Chamadas API: 6/179
#
# Chamadas API: 7/179
#
# Chamadas API: 8/179
#
# Chamadas API: 9/179
#
# Chamadas API: 10/179
#
# Chamadas API: 11/179
#
# Chamadas API: 12/179

# %%
# Sem conexão no end-point

if not "conjunto_dados" in locals():
    conjunto_dados = pd.read_csv(caminho_dataset, sep=';')

conjunto_dados['texto_original'] = conjunto_dados['tweet_texto']

conjunto_dados['tokens'] = conjunto_dados.apply(lambda x: nv.tokenizar(tweet_texto=x['tweet_texto'],
                                                                       chaves_busca=chaves_escolhidas,
                                                                       mencionados=x['tweet_usuarios_mencionados']),
                                                axis=1)

conjunto_dados['relacionamento_com_mencionados'] = conjunto_dados['tweet_usuarios_mencionados'].apply(lambda x: nv.relacionamento_com_mencionados(mencionados=x))

conjunto_dados['relacionamento_com_respondido'] = conjunto_dados['tweet_em_resposta'].apply(lambda x: nv.relacionamento_com_respondido(em_resposta=x))

conjunto_dados['possivel_crime'] = ''

conjunto_dados.to_csv(caminho_dataset, sep=';', index=False, encoding='utf-8-sig')
