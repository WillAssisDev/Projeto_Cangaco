# %% [markdown]
# <font color="green">**Atenção**: este notebook possui alto custo de processamento, então foi projetado para utilização na plataforma Google Colab.</font>

# %%
# !python -m spacy download pt_core_news_sm
# Out:
# ...
#      |████████████████████████████████| 21.2MB 1.3MB/s
# ...
#   Created wheel for pt-core-news-sm: filename=pt_core_news_sm-2.2.5-cp36-none-any.whl size=21186283 sha256=6e6e1be6a3e122ca8b2eabc4bc88b0db65e5526df44ea57b7def762c2e014d08
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kg94rleu/wheels/ea/94/74/ec9be8418e9231b471be5dc7e1b45dd670019a376a6b5bc1c0
# Successfully built pt-core-news-sm
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('pt_core_news_sm')

# %% [markdown]
# <h1><font color="red"><b>REINICIAR O KERNEL!!!</b></font></h1>

# %%
import sys
sys.path.insert(0, '/content/drive/My Drive/workspace/Projetos/projeto_cangaco')

# %%
import pandas as pd
from utilidades.caminho_projeto import CAMINHO_PROJETO
from maria_bonita.modelos.utilidades.W2V_Personalizado import Word2VecPersonalizado as w2v, CBOW, SKIPGRAM

# %%
dados = pd.read_csv(CAMINHO_PROJETO + 'maria_bonita/conjunto_dados/saida/misoginia.csv', sep=';')

# %%
w2v_cbow = w2v(CBOW, dados.tokens, log=True)

w2v_cbow.treinar()
w2v_cbow.salvar()
# Out:
# 2020-12-11 10:24:24,641 : - collecting all words and their counts
# 2020-12-11 10:24:24,642 : - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-12-11 10:24:24,643 : - collected 280 word types from a corpus of 496 raw words and 28 sentences
# 2020-12-11 10:24:24,645 : - Loading a fresh vocabulary
# 2020-12-11 10:24:24,649 : - effective_min_count=5 retains 15 unique words (5% of original 280, drops 265)
# 2020-12-11 10:24:24,651 : - effective_min_count=5 leaves 162 word corpus (32% of original 496, drops 334)
# 2020-12-11 10:24:24,652 : - deleting the raw counts dictionary of 280 items
# 2020-12-11 10:24:24,654 : - sample=0.001 downsamples 15 most-common words
# 2020-12-11 10:24:24,656 : - downsampling leaves estimated 21 word corpus (13.3% of prior 162)
# 2020-12-11 10:24:24,657 : - estimated required memory for 15 words and 300 dimensions: 43500 bytes
# 2020-12-11 10:24:24,658 : - resetting layer weights
# ...

# %%
w2v_skipgram = w2v(SKIPGRAM, dados.tokens, log=True)

w2v_skipgram.treinar()
w2v_skipgram.salvar()
# Out:
# 2020-12-11 10:24:37,159 : - collecting all words and their counts
# 2020-12-11 10:24:37,160 : - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-12-11 10:24:37,162 : - collected 280 word types from a corpus of 496 raw words and 28 sentences
# 2020-12-11 10:24:37,163 : - Loading a fresh vocabulary
# 2020-12-11 10:24:37,164 : - effective_min_count=5 retains 15 unique words (5% of original 280, drops 265)
# 2020-12-11 10:24:37,165 : - effective_min_count=5 leaves 162 word corpus (32% of original 496, drops 334)
# 2020-12-11 10:24:37,166 : - deleting the raw counts dictionary of 280 items
# 2020-12-11 10:24:37,167 : - sample=0.001 downsamples 15 most-common words
# 2020-12-11 10:24:37,168 : - downsampling leaves estimated 21 word corpus (13.3% of prior 162)
# 2020-12-11 10:24:37,169 : - estimated required memory for 15 words and 300 dimensions: 43500 bytes
# 2020-12-11 10:24:37,170 : - resetting layer weights
# ...
